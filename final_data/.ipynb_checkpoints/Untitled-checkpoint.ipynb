# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from datetime import datetime

# %%
all_file=os.listdir('./')
file=[]
for each_file in all_file:
    try:
        if  each_file.split('.')[1]=='csv':
            file.append(each_file)
    except: continue
file
# Out:
# ['40_data.csv',
#  '37_data.csv',
#  '36_data.csv',
#  '6_data.csv',
#  '57_data.csv',
#  '20_data.csv',
#  '21_data.csv',
#  '14_data.csv',
#  '15_data.csv',
#  '19_data.csv',
#  '18_data.csv',
#  '50_data.csv',
#  '51_data.csv',
#  '1_data.csv',
#  '26_data.csv',
#  '13_data.csv',
#  '47_data.csv',
#  '46_data.csv',
#  '31_data.csv',
#  '17_data.csv',
#  '16_data.csv',
#  '28_data.csv',
#  '5_data.csv',
#  '4_data.csv',
#  '54_data.csv',
#  '55_data.csv',
#  '23_data.csv',
#  '48_data.csv',
#  '43_data.csv',
#  '42_data.csv',
#  '34_data.csv',
#  '35_data.csv',
#  '44_data.csv',
#  '45_data.csv',
#  '33_data.csv',
#  '32_data.csv',
#  '8_data.csv',
#  '9_data.csv',
#  '59_data.csv',
#  '58_data.csv',
#  '10_data.csv',
#  '11_data.csv',
#  '53_data.csv',
#  '52_data.csv',
#  '2_data.csv',
#  '3_data.csv',
#  '24_data.csv',
#  '25_data.csv']

# %%
df=None
for f in file:

    data=pd.read_csv(f)
    if df is None:
        df=data
    else:
        df=pd.concat([df,data])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2448 entries, 0 to 28
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     2448 non-null   object
#  1   home_time                2448 non-null   float64
#  2   school_time              2448 non-null   float64
#  3   travel_time              2448 non-null   float64
#  4   date_in_week             2448 non-null   int64
#  5   cut_class                2448 non-null   float64
#  6   volunteer                2448 non-null   int64
#  7   recreational_activities  2307 non-null   float64
#  8   orthers                  2243 non-null   float64
#  9   working                  1416 non-null   float64
#  10  shopping                 1142 non-null   float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 229.5+ KB

# %%
# df=df.drop('Unnamed: 0',axis=1)
df.describe()
# Out:
#           home_time    school_time    travel_time  date_in_week    cut_class  \
# count  2.448000e+03    2448.000000    2448.000000   2448.000000  2448.000000
# mean   7.434019e+04    9409.950572    5144.855801      2.073938     0.152369
# std    8.137987e+04   26633.683336   25165.673467      1.950094     0.359452
# min    0.000000e+00       0.000000       0.000000     -1.000000     0.000000
# 25%    3.815875e+04       0.000000       0.000000      0.000000     0.000000
# 50%    7.080600e+04    1200.000000       0.000000      2.000000     0.000000
# 75%    8.526625e+04    7200.000000       0.000000      4.000000     0.000000
# max    1.645748e+06  550234.000000  629181.000000      5.000000     1.000000
#
#          volunteer  recreational_activities        orthers        working  \
# count  2448.000000              2307.000000    2243.000000    1416.000000
# mean     28.847222              3680.350238    3473.988408    5028.603107
# std      18.116488             13114.281989   19165.354626   19240.767489
# min       1.000000                 0.000000       0.000000       0.000000
# 25%      13.000000                 0.000000       0.000000       0.000000
# 50%      28.000000                 0.000000       0.000000       0.000000
# 75%      46.000000              3535.500000       0.000000       0.000000
# max      59.000000            251813.000000  395753.000000  232391.000000
#
#             shopping
# count    1142.000000
# mean      819.613835
# std      7681.506092
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max    117600.000000

# %%
def offset(data):
    try:
        if float(data)>86400:
            return 0
        return data
    except:
        return data
def to_min(time):
    try:
        return int(time/60)
    except: return time
    
time_type='%d:%m:%Y '
week=[]
def transform_week(time):
        time=datetime.strptime(time,time_type)
        return datetime.strftime(time,'%W')
for date in df.date.values:
    week.append(transform_week(date))
df['week']=week
for col in df.columns:
    df[col]=df[col].apply(lambda x: offset(x))
    df[col]=df[col].fillna(0)

for col in [ 'home_time', 'school_time', 'travel_time',
            'recreational_activities', 'orthers','working', 'shopping']:
    df[col]=df[col].apply(lambda x: to_min(x))
df['date_in_week']=df['date_in_week'].values+1
df['None_school_time']=1440-df.school_time-df.home_time
df.columns
# Out:
# Index(['date', 'home_time', 'school_time', 'travel_time', 'date_in_week',
#        'cut_class', 'volunteer', 'recreational_activities', 'orthers',
#        'working', 'shopping', 'week', 'None_school_time'],
#       dtype='object')

# %%
df
# Out:
#            date  home_time  school_time  travel_time  date_in_week  cut_class  \
# 0   03:04:2013          20          120            0             3        1.0
# 1   04:04:2013         400         1100            0             4        0.0
# 2   05:04:2013         440         1200            0             5        0.0
# 3   06:04:2013         620          600            0             6        0.0
# 4   07:04:2013           0          120            0             0        1.0
# ..          ...        ...          ...          ...           ...        ...
# 24  26:04:2013         361            0            0             5        0.0
# 25  28:03:2013           0           20            0             4        1.0
# 26  29:03:2013         179           40            0             5        1.0
# 27  30:03:2013           0            0            0             6        0.0
# 28  31:03:2013           0            0            0             0        0.0
#
#     volunteer  recreational_activities  orthers  working  shopping week  \
# 0          40                        0        0        0         0   13
# 1          40                        0        0        0         0   13
# 2          40                        0        0        0         0   13
# 3          40                        0        0        0         0   13
# 4          40                        0        0        0         0   13
# ..        ...                      ...      ...      ...       ...  ...
# 24         25                        0        0        0         0   16
# 25         25                        0        0        0         0   12
# 26         25                        0        0        0         0   12
# 27         25                        0        0        0         0   12
# 28         25                        0        0        0         0   12
#
#     None_school_time
# 0               1300
# 1                -60
# 2               -200
# 3                220
# 4               1320
# ..               ...
# 24              1079
# 25              1420
# 26              1221
# 27              1440
# 28              1440
#
# [2448 rows x 13 columns]

# %%
corr=df[[ 'home_time', 'school_time', 'travel_time', 'date_in_week',
        'recreational_activities', 'orthers',
       'working', 'shopping','None_school_time','cut_class']].corr()
ax,fig=plt.subplots(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(df,x='home_time',y='date_in_week',cbar=True)
# Out:
# <Axes: xlabel='home_time', ylabel='date_in_week'>

# %%
df
# Out:
#            date  home_time  school_time  travel_time  date_in_week  cut_class  \
# 0   03:04:2013          20          120            0             3        1.0
# 1   04:04:2013         400         1100            0             4        0.0
# 2   05:04:2013         440         1200            0             5        0.0
# 3   06:04:2013         620          600            0             6        0.0
# 4   07:04:2013           0          120            0             0        1.0
# ..          ...        ...          ...          ...           ...        ...
# 24  26:04:2013         361            0            0             5        0.0
# 25  28:03:2013           0           20            0             4        1.0
# 26  29:03:2013         179           40            0             5        1.0
# 27  30:03:2013           0            0            0             6        0.0
# 28  31:03:2013           0            0            0             0        0.0
#
#     volunteer  recreational_activities  orthers  working  shopping week  \
# 0          40                        0        0        0         0   13
# 1          40                        0        0        0         0   13
# 2          40                        0        0        0         0   13
# 3          40                        0        0        0         0   13
# 4          40                        0        0        0         0   13
# ..        ...                      ...      ...      ...       ...  ...
# 24         25                        0        0        0         0   16
# 25         25                        0        0        0         0   12
# 26         25                        0        0        0         0   12
# 27         25                        0        0        0         0   12
# 28         25                        0        0        0         0   12
#
#     None_school_time
# 0               1300
# 1                -60
# 2               -200
# 3                220
# 4               1320
# ..               ...
# 24              1079
# 25              1420
# 26              1221
# 27              1440
# 28              1440
#
# [2448 rows x 13 columns]

# %%
df=df.sort_values(['week','date'])
df
# Out:
#            date  home_time  school_time  travel_time  date_in_week  cut_class  \
# 50  27:03:2013         159           20            0             3        1.0
# 44  27:03:2013          80           79            0             3        0.0
# 51  27:03:2013          60           79            0             3        1.0
# 49  27:03:2013           0          119            0             3        0.0
# 41  27:03:2013          99          140            0             3        1.0
# ..          ...        ...          ...          ...           ...        ...
# 62  31:05:2013         421          279            0             5        0.0
# 63  31:05:2013           0            0            0             5        0.0
# 65  31:05:2013           0            0            0             5        0.0
# 61  31:05:2013        1410            0            0             5        0.0
# 66  31:05:2013        1427            0            0             5        0.0
#
#     volunteer  recreational_activities  orthers  working  shopping week  \
# 50          6                        0        0        0         0   12
# 44         57                        0        0        0         0   12
# 51         20                       39        0        0         0   12
# 49         15                       59        0        0         0   12
# 41         19                        0        0        0         0   12
# ..        ...                      ...      ...      ...       ...  ...
# 62         58                        0        0       10         0   21
# 63         11                      200        0        0         0   21
# 65         53                        0        0       20         0   21
# 61         52                        0        0        0         0   21
# 66          3                        0       19        0         0   21
#
#     None_school_time
# 50              1261
# 44              1281
# 51              1301
# 49              1321
# 41              1201
# ..               ...
# 62               740
# 63              1440
# 65              1440
# 61                30
# 66                13
#
# [2448 rows x 13 columns]

# %%
ax,fig=plt.subplots(figsize=(5,5))
sns.histplot(df,x='week',y='cut_class',cbar=True,bins=3)
plt.yticks([0,1])
# Out:
# ([<matplotlib.axis.YTick at 0x13b91fa60>,
#   <matplotlib.axis.YTick at 0x13b91f400>],
#  [Text(0, 0, '0'), Text(0, 1, '1')])

# %%
sns.countplot(df,x='week',hue='cut_class')
# Out:
# <Axes: xlabel='week', ylabel='count'>

# %%
sns.histplot(df,x='school_time',hue='cut_class')
# Out:
# <Axes: xlabel='school_time', ylabel='Count'>

# %%
df.school_time.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 50     20
# 44     79
# 51     79
# 49    119
# 41    140
#      ...
# 62    279
# 63      0
# 65      0
# 61      0
# 66      0
# Name: school_time, Length: 2448, dtype: int64>

# %%
df
# Out:
#            date  home_time  school_time  travel_time  date_in_week  cut_class  \
# 50  27:03:2013         159           20            0             3        1.0
# 44  27:03:2013          80           79            0             3        0.0
# 51  27:03:2013          60           79            0             3        1.0
# 49  27:03:2013           0          119            0             3        0.0
# 41  27:03:2013          99          140            0             3        1.0
# ..          ...        ...          ...          ...           ...        ...
# 62  31:05:2013         421          279            0             5        0.0
# 63  31:05:2013           0            0            0             5        0.0
# 65  31:05:2013           0            0            0             5        0.0
# 61  31:05:2013        1410            0            0             5        0.0
# 66  31:05:2013        1427            0            0             5        0.0
#
#     volunteer  recreational_activities  orthers  working  shopping week  \
# 50          6                        0        0        0         0   12
# 44         57                        0        0        0         0   12
# 51         20                       39        0        0         0   12
# 49         15                       59        0        0         0   12
# 41         19                        0        0        0         0   12
# ..        ...                      ...      ...      ...       ...  ...
# 62         58                        0        0       10         0   21
# 63         11                      200        0        0         0   21
# 65         53                        0        0       20         0   21
# 61         52                        0        0        0         0   21
# 66          3                        0       19        0         0   21
#
#     None_school_time
# 50              1261
# 44              1281
# 51              1301
# 49              1321
# 41              1201
# ..               ...
# 62               740
# 63              1440
# 65              1440
# 61                30
# 66                13
#
# [2448 rows x 13 columns]
