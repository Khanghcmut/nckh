# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3
from geopy.geocoders import bing
from geopy.geocoders import Photon
from geopy.extra.rate_limiter import RateLimiter

# %%
data=pd.read_csv('filtered_inactive_data.csv')
data=data.drop(['Unnamed: 0'],axis=1)
data.describe()
data_copy=data
data=data[data['tnv']==1]
data
# Out:
#      tnv     distance  velocity  accelerate  hour in date  min in date  \
# 0      1  7414.806863  3.089503    0.001287            19            2
# 1      1   221.913639  0.184928    0.000154            19           22
# 2      1   300.301541  0.250251    0.000209            21            2
# 3      1     6.492446  0.005410    0.000005            21           22
# 4      1    24.638362  0.020532    0.000017            21           42
# ..   ...          ...       ...         ...           ...          ...
# 743    1     0.000000  0.000000    0.000000             4           44
# 744    1  4881.950092  8.136583    0.013561             4           54
# 745    1  2711.284719  4.781807    0.008434             5            3
# 746    1  5298.167032  8.291341    0.012975             5           14
# 747    1  1772.072050  0.173784    0.000017             8            4
#
#       latitude  longitude        time  moving  active  time_difference
# ...

# %%
def to_address(lat,long,i):
    print(lat,"   ", long)
    geolocator = Nominatim(user_agent="Geocoordinateconverter")
#     geolocator=GoogleV3(api_key='AIzaSyCb0U_-yTWwrwNcrsHws8KzdcuQuo7frE4')
#     geolocator=Photon()
    reverse_func = RateLimiter(geolocator.reverse, min_delay_seconds=0.01)
    location = reverse_func(f'{lat},{long}',timeout=None)
    match i:
        case 1 : return location.raw['display_name']
        case 2 : return location.raw['type']
        case 3: return location.raw['addresstype']
        case 4: return location.raw['name']
        case 5: return location.raw['address'].get('country_code','')
data['address']=data.apply(lambda df:to_address(df['latitude'],df['longitude'],1),axis=1)
print('adress done')
data['type']=data.apply(lambda df:to_address(df['latitude'],df['longitude'],2),axis=1)
data['address_type']=data.apply(lambda df:to_address(df['latitude'],df['longitude'],3),axis=1)
data['hall']=data.apply(lambda df:to_address(df['latitude'],df['longitude'],4),axis=1)
data['nation']=data.apply(lambda df:to_address(df['latitude'],df['longitude'],5),axis=1)
# Out:
# 43.7051079     -72.2885239
# 43.7067246     -72.2872964
# 43.7089012     -72.2836734
# 43.7089485     -72.2839745
# 43.708769     -72.2837629
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 14
#       7     location = reverse_func(f'{lat},{long}',timeout=None)
#       8     match i:
#       9         case 1 : return location.raw['display_name']
#      10         case 2 : return location.raw['type']
#      11         case 3: return location.raw['addresstype']
#      12         case 4: return location.raw['name']
#      13         case 5: return location.raw['address'].get('country_code','')
# ---> 14 data['address']=data.apply(lambda df:to_address(df['latitude'],df['longitude'],1),axis=1)
#      15 print('adress done')
#      16 data['type']=data.apply(lambda df:to_address(df['latitude'],df['longitude'],2),axis=1)
#
# ...

# %%
data
