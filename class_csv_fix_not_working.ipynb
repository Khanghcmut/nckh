# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('class_fix.csv')
data
# Out:
#      1         1.1           2         3         4
# 0    2    ENGS 069    ENGS 022  ANTH 012       NaN
# 1    3    COSC 077    COSC 098  COSC 065       NaN
# 2    4    COSC 057    COSC 065       NaN       NaN
# 3    5    COSC 065         NaN       NaN       NaN
# 4    6    COSC 050    PSYC 028  COSC 065       NaN
# 5    7    COSC 077    COSC 060  COSC 065       NaN
# 6    8    CHIN 062  COSC 089 1  COSC 065       NaN
# 7    9    ANTH 050    COSC 065  COSC 099       NaN
# 8   10    COSC 050    BIOL 004  COSC 065       NaN
# 9   11  COSC 089 1    COSC 050  TUCK 003  COSC 065
# 10  12    COSC 070    COSC 065       NaN       NaN
# 11  13    COSC 065    COSC 027  COSC 020       NaN
# 12  14    EARS 003    SPAN 003  COSC 065       NaN
# 13  15    COSC 065    COSC 027       NaN       NaN
# 14  16  COSC 089 1     MUS 016  COSC 065       NaN
# 15  17  COSC 089 1    CHIN 033  TUCK 003  COSC 065
# 16  18    COSC 050    COSC 065  FILM 051       NaN
# ...

# %%
data=data.replace("COSC 089 1","COSC 089")

# %%
data
# Out:
#      1       1.1         2         3         4
# 0    2  ENGS 069  ENGS 022  ANTH 012       NaN
# 1    3  COSC 077  COSC 098  COSC 065       NaN
# 2    4  COSC 057  COSC 065       NaN       NaN
# 3    5  COSC 065       NaN       NaN       NaN
# 4    6  COSC 050  PSYC 028  COSC 065       NaN
# 5    7  COSC 077  COSC 060  COSC 065       NaN
# 6    8  CHIN 062  COSC 089  COSC 065       NaN
# 7    9  ANTH 050  COSC 065  COSC 099       NaN
# 8   10  COSC 050  BIOL 004  COSC 065       NaN
# 9   11  COSC 089  COSC 050  TUCK 003  COSC 065
# 10  12  COSC 070  COSC 065       NaN       NaN
# 11  13  COSC 065  COSC 027  COSC 020       NaN
# 12  14  EARS 003  SPAN 003  COSC 065       NaN
# 13  15  COSC 065  COSC 027       NaN       NaN
# 14  16  COSC 089   MUS 016  COSC 065       NaN
# 15  17  COSC 089  CHIN 033  TUCK 003  COSC 065
# 16  18  COSC 050  COSC 065  FILM 051       NaN
# 17  19  COSC 070  COSC 065       NaN       NaN
# 18  20  COSC 050   NAS 035  COSC 065       NaN
# ...

# %%
data.to_csv("Class.csv")
