# %%
import pandas as pd
from datetime import datetime
import os
def seconds(time):
        t0=datetime(1970,1,1)
        delta=time-t0
        return delta.total_seconds()
def to_date_time(x):
    return datetime.fromtimestamp(x)
def json_to_csv(i):
    jsonfile=f'./dataset/EMA/response/Stress'+f'/Stress_u{i:02d}.json'
    csvfile=f'./Stress_csv_new_1/Stress_u{i:02d}.csv'
    print(csvfile)
    df=pd.read_json(jsonfile)
    df=df[['level','resp_time']]
    df['resp_time']=df['resp_time']
    df['time']=df['resp_time'].apply(lambda time: seconds(time))-3600*5

    df['resp_time']=df['time'].apply(lambda x: to_date_time(x))
    print('abc')
    if i==0:
        print(df)
    try:
        df=df.dropna()
    except: pass
    df.to_csv(csvfile)
for i in range(61):
    try:
        json_to_csv(i)
    except:
        print('error')
# Out:
# ./Stress_csv_new_1/Stress_u00.csv
# abc
#     level           resp_time          time
# 0     NaN 2013-03-24 10:40:01  1.364096e+09
# 1     NaN 2013-03-24 10:40:58  1.364096e+09
# 2     NaN 2013-03-25 04:16:45  1.364160e+09
# 3     NaN 2013-03-25 02:00:18  1.364152e+09
# 4     NaN 2013-03-25 04:16:49  1.364160e+09
# ..    ...                 ...           ...
# 74    1.0 2013-06-03 08:00:04  1.370221e+09
# 75    1.0 2013-08-07 03:48:04  1.375822e+09
# 76    3.0 2013-08-08 02:47:33  1.375905e+09
# 77    1.0 2013-08-10 05:44:40  1.376088e+09
# 78    2.0 2013-08-16 02:56:08  1.376597e+09
#
# [79 rows x 3 columns]
# ./Stress_csv_new_1/Stress_u01.csv
# abc
# ./Stress_csv_new_1/Stress_u02.csv
# abc
# ./Stress_csv_new_1/Stress_u03.csv
# abc
# ./Stress_csv_new_1/Stress_u04.csv
# abc
# ./Stress_csv_new_1/Stress_u05.csv
# abc
# ./Stress_csv_new_1/Stress_u06.csv
# error
# ./Stress_csv_new_1/Stress_u07.csv
# abc
# ./Stress_csv_new_1/Stress_u08.csv
# abc
# ./Stress_csv_new_1/Stress_u09.csv
# abc
# ./Stress_csv_new_1/Stress_u10.csv
# abc
# ./Stress_csv_new_1/Stress_u11.csv
# error
# ./Stress_csv_new_1/Stress_u12.csv
# abc
# ./Stress_csv_new_1/Stress_u13.csv
# error
# ./Stress_csv_new_1/Stress_u14.csv
# abc
# ./Stress_csv_new_1/Stress_u15.csv
# abc
# ./Stress_csv_new_1/Stress_u16.csv
# abc
# ./Stress_csv_new_1/Stress_u17.csv
# abc
# ./Stress_csv_new_1/Stress_u18.csv
# abc
# ./Stress_csv_new_1/Stress_u19.csv
# abc
# ./Stress_csv_new_1/Stress_u20.csv
# abc
# ./Stress_csv_new_1/Stress_u21.csv
# error
# ./Stress_csv_new_1/Stress_u22.csv
# abc
# ./Stress_csv_new_1/Stress_u23.csv
# abc
# ./Stress_csv_new_1/Stress_u24.csv
# abc
# ./Stress_csv_new_1/Stress_u25.csv
# abc
# ./Stress_csv_new_1/Stress_u26.csv
# error
# ./Stress_csv_new_1/Stress_u27.csv
# abc
# ./Stress_csv_new_1/Stress_u28.csv
# error
# ./Stress_csv_new_1/Stress_u29.csv
# error
# ./Stress_csv_new_1/Stress_u30.csv
# abc
# ./Stress_csv_new_1/Stress_u31.csv
# abc
# ./Stress_csv_new_1/Stress_u32.csv
# abc
# ./Stress_csv_new_1/Stress_u33.csv
# abc
# ./Stress_csv_new_1/Stress_u34.csv
# abc
# ./Stress_csv_new_1/Stress_u35.csv
# abc
# ./Stress_csv_new_1/Stress_u36.csv
# abc
# ./Stress_csv_new_1/Stress_u37.csv
# error
# ./Stress_csv_new_1/Stress_u38.csv
# error
# ./Stress_csv_new_1/Stress_u39.csv
# abc
# ./Stress_csv_new_1/Stress_u40.csv
# error
# ./Stress_csv_new_1/Stress_u41.csv
# abc
# ./Stress_csv_new_1/Stress_u42.csv
# abc
# ./Stress_csv_new_1/Stress_u43.csv
# abc
# ./Stress_csv_new_1/Stress_u44.csv
# abc
# ./Stress_csv_new_1/Stress_u45.csv
# abc
# ./Stress_csv_new_1/Stress_u46.csv
# abc
# ./Stress_csv_new_1/Stress_u47.csv
# abc
# ./Stress_csv_new_1/Stress_u48.csv
# error
# ./Stress_csv_new_1/Stress_u49.csv
# abc
# ./Stress_csv_new_1/Stress_u50.csv
# abc
# ./Stress_csv_new_1/Stress_u51.csv
# abc
# ./Stress_csv_new_1/Stress_u52.csv
# abc
# ./Stress_csv_new_1/Stress_u53.csv
# abc
# ./Stress_csv_new_1/Stress_u54.csv
# abc
# ./Stress_csv_new_1/Stress_u55.csv
# error
# ./Stress_csv_new_1/Stress_u56.csv
# abc
# ./Stress_csv_new_1/Stress_u57.csv
# abc
# ./Stress_csv_new_1/Stress_u58.csv
# abc
# ./Stress_csv_new_1/Stress_u59.csv
# abc
# ./Stress_csv_new_1/Stress_u60.csv
# error
