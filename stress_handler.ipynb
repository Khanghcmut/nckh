# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
data=pd.read_csv('./Stress_csv/Stress_u01.csv')
data=data[['level','resp_time']]
data
# Out:
#     level            resp_time
# 0     4.0  2013-03-27 04:45:45
# 1     1.0  2013-03-30 22:27:26
# 2     1.0  2013-03-29 19:45:25
# 3     4.0  2013-03-28 23:53:09
# 4     5.0  2013-03-30 00:32:58
# 5     1.0  2013-03-31 18:49:27
# 6     2.0  2013-04-01 02:45:54
# 7     1.0  2013-04-03 06:03:04
# 8     4.0  2013-04-04 07:28:35
# 9     4.0  2013-04-05 06:08:42
# 10    4.0  2013-04-06 01:26:41
# 11    5.0  2013-04-06 09:39:30
# 12    1.0  2013-04-07 21:21:54
# 13    1.0  2013-04-09 04:50:01
# 14    1.0  2013-04-10 22:33:15
# 15    2.0  2013-04-10 02:59:22
# 16    1.0  2013-04-16 04:24:02
# 17    1.0  2013-04-11 02:03:16
# 18    1.0  2013-04-12 02:44:19
# 19    4.0  2013-04-13 22:54:36
# 20    1.0  2013-04-14 23:14:15
# 21    1.0  2013-04-16 01:52:24
# 22    1.0  2013-04-17 04:01:47
# 23    4.0  2013-04-19 00:32:42
# 24    4.0  2013-04-20 06:44:52
# 25    2.0  2013-04-28 07:47:46
# 26    2.0  2013-04-28 21:44:49
# 27    1.0  2013-04-26 18:03:22
# 28    2.0  2013-04-28 19:34:02
# ...

# %%
from datetime import datetime
def seconds(time):
    t0=datetime(1970,1,1)
    time = datetime.strptime(time, '%Y-%m-%d %H:%M:%S')
    delta=time-t0
    return delta.total_seconds()
data['time']=data['resp_time'].apply(lambda time: seconds(time))

# %%
data
# Out:
#     level            resp_time          time
# 0     4.0  2013-03-27 04:45:45  1.364360e+09
# 1     1.0  2013-03-30 22:27:26  1.364682e+09
# 2     1.0  2013-03-29 19:45:25  1.364586e+09
# 3     4.0  2013-03-28 23:53:09  1.364515e+09
# 4     5.0  2013-03-30 00:32:58  1.364604e+09
# 5     1.0  2013-03-31 18:49:27  1.364756e+09
# 6     2.0  2013-04-01 02:45:54  1.364784e+09
# 7     1.0  2013-04-03 06:03:04  1.364969e+09
# 8     4.0  2013-04-04 07:28:35  1.365061e+09
# 9     4.0  2013-04-05 06:08:42  1.365142e+09
# 10    4.0  2013-04-06 01:26:41  1.365212e+09
# 11    5.0  2013-04-06 09:39:30  1.365241e+09
# 12    1.0  2013-04-07 21:21:54  1.365370e+09
# 13    1.0  2013-04-09 04:50:01  1.365483e+09
# 14    1.0  2013-04-10 22:33:15  1.365633e+09
# 15    2.0  2013-04-10 02:59:22  1.365563e+09
# 16    1.0  2013-04-16 04:24:02  1.366086e+09
# 17    1.0  2013-04-11 02:03:16  1.365646e+09
# 18    1.0  2013-04-12 02:44:19  1.365735e+09
# 19    4.0  2013-04-13 22:54:36  1.365894e+09
# ...

# %%
import pandas as pd
from datetime import datetime
import os
def seconds(time):
        t0=datetime(1970,1,1)
        time = datetime.strptime(time, '%Y-%m-%d %H:%M:%S')
        delta=time-t0
        return delta.total_seconds()
def json_to_csv(i):
    jsonfile='./dataset/EMA/response/Stress'+f'/Stress_u{i:02d}.json'
    csvfile= f'./stress_new/Stress_u{i:02d}.csv'
    print(csvfile)
    df=pd.read_json(jsonfile)

    df=df[['level','resp_time']]
    
    df=df.dropna()
#     df['time']=df['resp_time'].apply(lambda time: seconds(time))
    print(df.info())
    df.to_csv(csvfile)
for i in range(60):
    try:
        json_to_csv(i)
    except:
        pass
# Out:
# ./stress_new/Stress_u00.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 74 entries, 5 to 78
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   level      74 non-null     float64
#  1   resp_time  74 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.7 KB
# None
# ./stress_new/Stress_u01.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, 0 to 35
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   level      32 non-null     float64
#  1   resp_time  32 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 768.0 bytes
# None
# ./stress_new/Stress_u02.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 5 to 34
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
# ...
